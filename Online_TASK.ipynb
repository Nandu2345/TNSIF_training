# %% [markdown]
# <a href="https://colab.research.google.com/github/Nandu2345/TNSIF_training/blob/main/Online_TASK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
student_names = []
name = input("Enter Student Name: ")
age = int(input("Enter Age: "))
num_subjects = int(input("Enter Number of Subjects: "))
student_names.append(name)
subjects = set()
student_info = (age,)
marks = {}
for i in range(num_subjects):
    print("Enter Subject", i + 1)
    subject = input("Subject Name: ")
    mark = int(input("Marks: "))
    subjects.add(subject)
    marks[subject] = mark
total_marks = sum(marks.values())
average_marks = total_marks / num_subjects
print("\n----- REPORT CARD -----")
print("Name:", name)
print("Age:", student_info[0])
print("Subjects:", subjects)
print("\nMarks:")
for subject in marks:
    print(subject, ":", marks[subject])
print("Total Marks:", total_marks)
print("Average Marks:", average_marks)
# Out:
# Enter Student Name: nandini
# Enter Age: 21
# Enter Number of Subjects: 3
# Enter Subject 1
# Subject Name: ds
# Marks: 19
# Enter Subject 2
# Subject Name: 18
# Marks: 18
# Enter Subject 3
# Subject Name: os
# Marks: 20
#
# ----- REPORT CARD -----
# Name: nandini
# Age: 21
# Subjects: {'18', 'ds', 'os'}
#
# Marks:
# ds : 19
# 18 : 18
# os : 20
# Total Marks: 57
# Average Marks: 19.0
